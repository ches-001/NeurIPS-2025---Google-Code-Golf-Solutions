# %% [markdown]
# # Google Code Golf 2025
#
# ## Objective: Solve all 400 puzzles with the least amount of code

# %%
import os
import glob
from copy import deepcopy
from code_golf_utils import *

PUZZLES_PATH = "dataset\google-code-golf-2025"
SOLUTIONS_PATH = "tasks"
LABEL = "train"
solutions = glob.glob(os.path.join(SOLUTIONS_PATH, '*.py'))
print(f"Number of puzzle files: {len(glob.glob(os.path.join(PUZZLES_PATH, '*.json')))}")
print(f"Number of solutions: {len(solutions)}")
print(f"Uncompressed Competition score: {sum([max(1, 2500-os.path.getsize(f)) for f in solutions])}")
print(f"Uncompressed Average filesize: {sum([os.path.getsize(f) for f in solutions])/len(solutions) :.4f} bytes")
# Out:
# Number of puzzle files: 400
# Number of solutions: 400
# Uncompressed Competition score: 933071
# Uncompressed Average filesize: 167.3225 bytes

# %%
def plot(X, ax):
    X=[list(tuple(row)) for row in X]
    for r in range(len(X)):
        for c in range(len(X[0])):
            X[r][c] = colors[X[r][c]]
    ax.imshow(X)

# %% [markdown]
# # [Task 001](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task001.py)

# %%
puzzle_data = load_examples(1)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(1, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 6019.09it/s]
# 262it [00:00, 16460.32it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 61 bytes.
# Next steps:
#  * Copy it into a file named task001.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 002](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task002.py)

# %%
puzzle_data = load_examples(2)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(2, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 206.02it/s]
# 262it [00:01, 160.43it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 125 bytes.
# Next steps:
#  * Copy it into a file named task002.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 003](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task003.py)

# %%
puzzle_data = load_examples(3)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(3, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 25847.36it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 66 bytes.
# Next steps:
#  * Copy it into a file named task003.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 004](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task004.py)

# %%
puzzle_data = load_examples(4)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(4, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2984.56it/s]
# 262it [00:00, 6876.60it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 195 bytes.
# Next steps:
#  * Copy it into a file named task004.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 005](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task005.py)

# %%
puzzle_data = load_examples(5)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(5, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1008.06it/s]
# 262it [00:00, 1020.77it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 342 bytes.
# Next steps:
#  * Copy it into a file named task005.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 006](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task006.py)

# %%
puzzle_data = load_examples(6)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(6, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 43669.83it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 66 bytes.
# Next steps:
#  * Copy it into a file named task006.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 007](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task007.py)

# %%
puzzle_data = load_examples(7)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(7, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 7278.50it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 104 bytes.
# Next steps:
#  * Copy it into a file named task007.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 008](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task008.py)

# %%
puzzle_data = load_examples(8)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(8, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 7680.91it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 176 bytes.
# Next steps:
#  * Copy it into a file named task008.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 009](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task009.py)

# %%
puzzle_data = load_examples(9)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(9, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1362.45it/s]
# 261it [00:00, 1225.76it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 178 bytes.
# Next steps:
#  * Copy it into a file named task009.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 010](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task010.py)

# %%
puzzle_data = load_examples(10)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(10, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 11388.00it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 93 bytes.
# Next steps:
#  * Copy it into a file named task010.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 011](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task011.py)

# %%
puzzle_data = load_examples(11)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(11, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4995.60it/s]
# 262it [00:00, 7278.02it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 195 bytes.
# Next steps:
#  * Copy it into a file named task011.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 012](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task012.py)

# %%
puzzle_data = load_examples(12)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(12, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 444.63it/s]
# 262it [00:00, 758.44it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 217 bytes.
# Next steps:
#  * Copy it into a file named task012.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 013](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task013.py)

# %%
puzzle_data = load_examples(13)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(13, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5006.33it/s]
# 262it [00:00, 5038.87it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 238 bytes.
# Next steps:
#  * Copy it into a file named task013.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 014](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task014.py)

# %%
puzzle_data = load_examples(14)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(14, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3999.34it/s]
# 262it [00:00, 5575.49it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 118 bytes.
# Next steps:
#  * Copy it into a file named task014.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 015](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task015.py)

# %%
puzzle_data = load_examples(15)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(15, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4005.06it/s]
# 261it [00:00, 6868.66it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 134 bytes.
# Next steps:
#  * Copy it into a file named task015.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 016](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task016.py)

# %%
puzzle_data = load_examples(16)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(16, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 52463.84it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 59 bytes.
# Next steps:
#  * Copy it into a file named task016.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 017](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task017.py)

# %%
puzzle_data = load_examples(17)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:5])

verify_program(17, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2002.05it/s]
# 262it [00:00, 2809.62it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 223 bytes.
# Next steps:
#  * Copy it into a file named task017.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 018](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task018.py)

# %%
puzzle_data = load_examples(18)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(18, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 28.17it/s]
# 262it [00:13, 19.89it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 705 bytes.
# Next steps:
#  * Copy it into a file named task018.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 019](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task019.py)

# %%
puzzle_data = load_examples(19)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(19, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5889.22it/s]
# 262it [00:00, 9005.74it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 163 bytes.
# Next steps:
#  * Copy it into a file named task019.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 020](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task020.py)

# %%
puzzle_data = load_examples(20)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(20, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 7916.40it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 213 bytes.
# Next steps:
#  * Copy it into a file named task020.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 021](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task021.py)

# %%
puzzle_data = load_examples(21)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(21, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 5126.36it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 79 bytes.
# Next steps:
#  * Copy it into a file named task021.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 022](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task022.py)

# %%
puzzle_data = load_examples(22)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(22, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 19995.41it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 176 bytes.
# Next steps:
#  * Copy it into a file named task022.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 023](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task023.py)

# %%
puzzle_data = load_examples(23)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(23, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 656.82it/s]
# 262it [00:00, 563.44it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 355 bytes.
# Next steps:
#  * Copy it into a file named task023.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 024](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task024.py)

# %%
puzzle_data = load_examples(24)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(24, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 7683.65it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task024.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 025](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task025.py)

# %%
puzzle_data = load_examples(25)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(25, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2087.50it/s]
# 262it [00:00, 3404.26it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 216 bytes.
# Next steps:
#  * Copy it into a file named task025.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 026](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task026.py)

# %%
puzzle_data = load_examples(26)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(26, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 6068.44it/s]
# 262it [00:00, 29126.34it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 57 bytes.
# Next steps:
#  * Copy it into a file named task026.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 027](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task027.py)

# %%
puzzle_data = load_examples(27)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[19:21])

verify_program(27, puzzle_data)
# Out:
# num problems: 261
# 4it [00:00, 4003.15it/s]
# 261it [00:00, 11369.04it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 152 bytes.
# Next steps:
#  * Copy it into a file named task027.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 028](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task028.py)

# %%
puzzle_data = load_examples(28)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(28, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1508.74it/s]
# 262it [00:00, 8479.49it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 111 bytes.
# Next steps:
#  * Copy it into a file named task028.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 029](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task029.py)

# %%
puzzle_data = load_examples(29)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[7:10])

verify_program(29, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, 3995.53it/s]
# 262it [00:00, 6076.05it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 152 bytes.
# Next steps:
#  * Copy it into a file named task029.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 030](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task030.py)

# %%
puzzle_data = load_examples(30)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(30, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4181.76it/s]
# 262it [00:00, 13712.01it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 163 bytes.
# Next steps:
#  * Copy it into a file named task030.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 031](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task031.py)

# %%
puzzle_data = load_examples(31)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(31, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13794.97it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 50 bytes.
# Next steps:
#  * Copy it into a file named task031.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 032](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task032.py)

# %%
puzzle_data = load_examples(32)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(32, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4008.89it/s]
# 262it [00:00, 29104.74it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 39 bytes.
# Next steps:
#  * Copy it into a file named task032.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 033](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task033.py)

# %%
puzzle_data = load_examples(33)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(33, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4739.33it/s]
# 261it [00:00, 4342.34it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 83 bytes.
# Next steps:
#  * Copy it into a file named task033.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 034](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task034.py)

# %%
puzzle_data = load_examples(34)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(34, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4970.73it/s]
# 262it [00:00, 13116.27it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 244 bytes.
# Next steps:
#  * Copy it into a file named task034.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 035](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task035.py)

# %%
puzzle_data = load_examples(35)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(35, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1995.39it/s]
# 262it [00:00, 2448.86it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task035.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 036](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task036.py)

# %%
puzzle_data = load_examples(36)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(36, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 272.79it/s]
# 262it [00:00, 295.01it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 136 bytes.
# Next steps:
#  * Copy it into a file named task036.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 037](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task037.py)

# %%
puzzle_data = load_examples(37)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(37, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4006.98it/s]
# 262it [00:00, 8453.66it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task037.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 038](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task038.py)

# %%
puzzle_data = load_examples(38)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(38, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 23611.10it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 108 bytes.
# Next steps:
#  * Copy it into a file named task038.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 039](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task039.py)

# %%
puzzle_data = load_examples(39)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(39, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3023.28it/s]
# 261it [00:00, 16226.63it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 134 bytes.
# Next steps:
#  * Copy it into a file named task039.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 040](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task040.py)

# %%
puzzle_data = load_examples(40)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(40, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3982.25it/s]
# 262it [00:00, 8466.68it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 107 bytes.
# Next steps:
#  * Copy it into a file named task040.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 041](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task041.py)

# %%
puzzle_data = load_examples(41)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(41, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3829.54it/s]
# 262it [00:00, 11916.93it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 66 bytes.
# Next steps:
#  * Copy it into a file named task041.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 042](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task042.py)

# %%
puzzle_data = load_examples(42)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(42, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3671.97it/s]
# 262it [00:00, 4288.12it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 385 bytes.
# Next steps:
#  * Copy it into a file named task042.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 043](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task043.py)

# %%
puzzle_data = load_examples(43)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(43, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3996.48it/s]
# 262it [00:00, 9002.64it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 77 bytes.
# Next steps:
#  * Copy it into a file named task043.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 044](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task044.py)

# %%
puzzle_data = load_examples(44)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(44, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, 497.38it/s]
# 262it [00:00, 510.64it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 812 bytes.
# Next steps:
#  * Copy it into a file named task044.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 045](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task045.py)

# %%
puzzle_data = load_examples(45)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(45, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4514.86it/s]
# 261it [00:00, 11871.19it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 60 bytes.
# Next steps:
#  * Copy it into a file named task045.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 046](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task046.py)

# %%
puzzle_data = load_examples(46)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(46, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 20014.35it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 492 bytes.
# Next steps:
#  * Copy it into a file named task046.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 047](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task047.py)

# %%
puzzle_data = load_examples(47)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(47, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3226.39it/s]
# 262it [00:00, 7257.01it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 108 bytes.
# Next steps:
#  * Copy it into a file named task047.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 048](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task048.py)

# %%
puzzle_data = load_examples(48)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(48, puzzle_data)
# Out:
# num problems: 6
# 8it [00:00, 7932.49it/s]
# 262it [00:00, 15405.54it/s]
# Results on ARC-AGI examples: 8 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
# Your code IS READY for submission!
# Its length appears to be 182 bytes.
# Next steps:
#  * Copy it into a file named task048.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 049](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task049.py)

# %%
puzzle_data = load_examples(49)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(49, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 6004.73it/s]
# 262it [00:00, 10485.46it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 115 bytes.
# Next steps:
#  * Copy it into a file named task049.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 050](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task050.py)

# %%
puzzle_data = load_examples(50)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(50, puzzle_data)
# Out:
# num problems: 8
# 9it [00:00, 10183.10it/s]
# 262it [00:00, 10425.97it/s]
# Results on ARC-AGI examples: 9 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 108 bytes.
# Next steps:
#  * Copy it into a file named task050.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 051](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task051.py)

# %%
puzzle_data = load_examples(51)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(51, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 364.06it/s]
# 261it [00:01, 236.95it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 152 bytes.
# Next steps:
#  * Copy it into a file named task051.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 052](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task052.py)

# %%
puzzle_data = load_examples(52)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(52, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 52396.30it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 43 bytes.
# Next steps:
#  * Copy it into a file named task052.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 053](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task053.py)

# %%
puzzle_data = load_examples(53)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(53, puzzle_data)
# Out:
# num problems: 4
# 6it [00:00, ?it/s]
# 54it [00:00, 54681.90it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 54 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 22 bytes.
# Next steps:
#  * Copy it into a file named task053.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 054](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task054.py)

# %%
puzzle_data = load_examples(54)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:2])

verify_program(54, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 800.29it/s]
# 262it [00:00, 864.69it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 790 bytes.
# Next steps:
#  * Copy it into a file named task054.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 055](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task055.py)

# %%
puzzle_data = load_examples(55)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(55, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2895.95it/s]
# 262it [00:00, 2031.15it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 193 bytes.
# Next steps:
#  * Copy it into a file named task055.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 056](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task056.py)

# %%
puzzle_data = load_examples(56)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(56, puzzle_data)
# Out:
# num problems: 7
# 10it [00:00, ?it/s]
# 36it [00:00, 34679.59it/s]
# Results on ARC-AGI examples: 10 pass, 0 fail
# Results on ARC-GEN examples: 36 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 76 bytes.
# Next steps:
#  * Copy it into a file named task056.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 057](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task057.py)

# %%
puzzle_data = load_examples(57)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(57, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 28685.20it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 55 bytes.
# Next steps:
#  * Copy it into a file named task057.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 058](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task058.py)

# %%
puzzle_data = load_examples(58)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[0:5])

verify_program(58, puzzle_data)
# Out:
# num problems: 16
# 6it [00:00, 5959.23it/s]
# 16it [00:00, 7902.60it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 16 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 251 bytes.
# Next steps:
#  * Copy it into a file named task058.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 059](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task059.py)

# %%
puzzle_data = load_examples(59)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(59, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3886.31it/s]
# 262it [00:00, 7261.33it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 202 bytes.
# Next steps:
#  * Copy it into a file named task059.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 060](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task060.py)

# %%
puzzle_data = load_examples(60)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(60, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2995.22it/s]
# 262it [00:00, 20166.03it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 53 bytes.
# Next steps:
#  * Copy it into a file named task060.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 061](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task061.py)

# %%
puzzle_data = load_examples(61)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(61, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 357.69it/s]
# 262it [00:00, 348.43it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 70 bytes.
# Next steps:
#  * Copy it into a file named task061.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 062](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task062.py)

# %%
puzzle_data = load_examples(62)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(62, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5003.94it/s]
# 262it [00:00, 8453.59it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 196 bytes.
# Next steps:
#  * Copy it into a file named task062.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 063](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task063.py)

# %%
puzzle_data = load_examples(63)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(63, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4010.81it/s]
# 262it [00:00, 5940.68it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task063.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 064](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task064.py)

# %%
puzzle_data = load_examples(64)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(64, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2480.66it/s]
# 262it [00:00, 1701.22it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 201 bytes.
# Next steps:
#  * Copy it into a file named task064.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 065](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task065.py)

# %%
puzzle_data = load_examples(65)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(65, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 11398.63it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 129 bytes.
# Next steps:
#  * Copy it into a file named task065.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 066](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task066.py)

# %%
puzzle_data = load_examples(66)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(66, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2001.58it/s]
# 262it [00:00, 2693.66it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 541 bytes.
# Next steps:
#  * Copy it into a file named task066.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 067](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task067.py)

# %%
puzzle_data = load_examples(67)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(67, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 37438.94it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 33 bytes.
# Next steps:
#  * Copy it into a file named task067.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 068](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task068.py)

# %%
puzzle_data = load_examples(68)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(68, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3509.88it/s]
# 262it [00:00, 5201.34it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 149 bytes.
# Next steps:
#  * Copy it into a file named task068.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 069](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task069.py)

# %%
puzzle_data = load_examples(69)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(69, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 261it [00:00, 10883.03it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 232 bytes.
# Next steps:
#  * Copy it into a file named task069.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 070](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task070.py)

# %%
puzzle_data = load_examples(70)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(70, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 656.18it/s]
# 262it [00:00, 698.68it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 152 bytes.
# Next steps:
#  * Copy it into a file named task070.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 071](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task071.py)

# %%
puzzle_data = load_examples(71)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(71, puzzle_data)
# Out:
# num problems: 262
# 3it [00:00, 2727.12it/s]
# 262it [00:00, 5333.62it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task071.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 072](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task072.py)

# %%
puzzle_data = load_examples(72)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(72, puzzle_data)
# Out:
# num problems: 4
# 6it [00:00, ?it/s]
# 262it [00:00, 20097.43it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 72 bytes.
# Next steps:
#  * Copy it into a file named task072.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 073](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task073.py)

# %%
puzzle_data = load_examples(73)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(73, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3998.38it/s]
# 11it [00:00, 11013.93it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 11 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 67 bytes.
# Next steps:
#  * Copy it into a file named task073.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 074](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task074.py)

# %%
puzzle_data = load_examples(74)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(74, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 999.31it/s]
# 262it [00:00, 1143.57it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 135 bytes.
# Next steps:
#  * Copy it into a file named task074.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 075](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task075.py)

# %%
puzzle_data = load_examples(75)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(75, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 10876.22it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 136 bytes.
# Next steps:
#  * Copy it into a file named task075.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 076](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task076.py)

# %%
puzzle_data = load_examples(76)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(76, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 667.75it/s]
# 262it [00:00, 619.32it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 714 bytes.
# Next steps:
#  * Copy it into a file named task076.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 077](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task077.py)

# %%
puzzle_data = load_examples(77)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(77, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 656.39it/s]
# 262it [00:00, 605.55it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 167 bytes.
# Next steps:
#  * Copy it into a file named task077.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 078](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task078.py)

# %%
puzzle_data = load_examples(78)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(78, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3978.47it/s]
# 262it [00:00, 10482.26it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 102 bytes.
# Next steps:
#  * Copy it into a file named task078.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 079](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task079.py)

# %%
puzzle_data = load_examples(79)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(79, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3594.86it/s]
# 262it [00:00, 4596.54it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 139 bytes.
# Next steps:
#  * Copy it into a file named task079.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 080](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task080.py)

# %%
puzzle_data = load_examples(80)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(80, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1999.91it/s]
# 262it [00:00, 1895.69it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 403 bytes.
# Next steps:
#  * Copy it into a file named task080.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 081](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task081.py)

# %%
puzzle_data = load_examples(81)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(81, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3003.80it/s]
# 261it [00:00, 11346.88it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 130 bytes.
# Next steps:
#  * Copy it into a file named task081.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 082](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task082.py)

# %%
puzzle_data = load_examples(82)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(82, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 16491.94it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 92 bytes.
# Next steps:
#  * Copy it into a file named task082.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 083](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task083.py)

# %%
puzzle_data = load_examples(83)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(83, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4440.77it/s]
# 262it [00:00, 23810.10it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 40 bytes.
# Next steps:
#  * Copy it into a file named task083.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 084](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task084.py)

# %%
puzzle_data = load_examples(84)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(84, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 171it [00:00, 8109.29it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 171 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 71 bytes.
# Next steps:
#  * Copy it into a file named task084.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 085](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task085.py)

# %%
puzzle_data = load_examples(85)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(85, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3387.06it/s]
# 262it [00:00, 5132.92it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 89 bytes.
# Next steps:
#  * Copy it into a file named task085.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 086](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task086.py)

# %%
puzzle_data = load_examples(86)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(86, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 265.52it/s]
# 262it [00:01, 212.83it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 342 bytes.
# Next steps:
#  * Copy it into a file named task086.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 087](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task087.py)

# %%
puzzle_data = load_examples(87)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(87, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 261it [00:00, 52997.35it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 36 bytes.
# Next steps:
#  * Copy it into a file named task087.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 088](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task088.py)

# %%
puzzle_data = load_examples(88)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(88, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4986.10it/s]
# 262it [00:00, 9357.34it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 149 bytes.
# Next steps:
#  * Copy it into a file named task088.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 089](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task089.py)

# %%
puzzle_data = load_examples(89)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[21:24])

verify_program(89, puzzle_data)
# Out:
# num problems: 262
# 5it [00:00, 1247.19it/s]
# 262it [00:00, 1669.12it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 409 bytes.
# Next steps:
#  * Copy it into a file named task089.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 090](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task090.py)

# %%
puzzle_data = load_examples(90)
label = "test"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(90, puzzle_data)
# Out:
# num problems: 1
# 5it [00:00, 1000.55it/s]
# 262it [00:00, 702.21it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 223 bytes.
# Next steps:
#  * Copy it into a file named task090.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 091](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task091.py)

# %%
puzzle_data = load_examples(91)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(91, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4004.11it/s]
# 262it [00:00, 13102.36it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 120 bytes.
# Next steps:
#  * Copy it into a file named task091.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 092](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task092.py)

# %%
puzzle_data = load_examples(92)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(92, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1013.69it/s]
# 262it [00:00, 1013.88it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 154 bytes.
# Next steps:
#  * Copy it into a file named task092.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 093](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task093.py)

# %%
puzzle_data = load_examples(93)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(93, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3659.15it/s]
# 261it [00:00, 5426.84it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 181 bytes.
# Next steps:
#  * Copy it into a file named task093.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 094](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task094.py)

# %%
puzzle_data = load_examples(94)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[259:])

verify_program(94, puzzle_data)
# Out:
# num problems: 262
# 3it [00:00, 2998.79it/s]
# 262it [00:00, 4093.86it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 171 bytes.
# Next steps:
#  * Copy it into a file named task094.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 095](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task095.py)

# %%
puzzle_data = load_examples(95)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(95, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3432.33it/s]
# 262it [00:00, 7940.77it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 106 bytes.
# Next steps:
#  * Copy it into a file named task095.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 096](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task096.py)

# %%
puzzle_data = load_examples(96)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(96, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 442.04it/s]
# 262it [00:00, 707.86it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 396 bytes.
# Next steps:
#  * Copy it into a file named task096.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 097](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task097.py)

# %%
puzzle_data = load_examples(97)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(97, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1667.98it/s]
# 262it [00:00, 3081.98it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 142 bytes.
# Next steps:
#  * Copy it into a file named task097.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 098](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task098.py)

# %%
puzzle_data = load_examples(98)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(98, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3894.43it/s]
# 262it [00:00, 5028.84it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 142 bytes.
# Next steps:
#  * Copy it into a file named task098.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 099](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task099.py)

# %%
puzzle_data = load_examples(99)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(99, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1346.27it/s]
# 261it [00:00, 1375.34it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 168 bytes.
# Next steps:
#  * Copy it into a file named task099.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 100](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task100.py)

# %%
puzzle_data = load_examples(100)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(100, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13832.83it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 147 bytes.
# Next steps:
#  * Copy it into a file named task100.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 101](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task101.py)

# %%
puzzle_data = load_examples(101)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(101, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 799.87it/s]
# 262it [00:00, 1700.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 666 bytes.
# Next steps:
#  * Copy it into a file named task101.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 102](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task102.py)

# %%
puzzle_data = load_examples(102)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(102, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 441.63it/s]
# 262it [00:00, 507.89it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 225 bytes.
# Next steps:
#  * Copy it into a file named task102.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 103](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task103.py)

# %%
puzzle_data = load_examples(103)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(103, puzzle_data)
# Out:
# num problems: 6
# 8it [00:00, ?it/s]
# 215it [00:00, 53785.96it/s]
# Results on ARC-AGI examples: 8 pass, 0 fail
# Results on ARC-GEN examples: 215 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 32 bytes.
# Next steps:
#  * Copy it into a file named task103.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 104](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task104.py)

# %%
puzzle_data = load_examples(104)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(104, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 4it [00:00, 4001.24it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 4 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 132 bytes.
# Next steps:
#  * Copy it into a file named task104.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 105](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task105.py)

# %%
puzzle_data = load_examples(105)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[80:83])

verify_program(105, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, 3609.56it/s]
# 262it [00:00, 3636.94it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 244 bytes.
# Next steps:
#  * Copy it into a file named task105.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 106](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task106.py)

# %%
puzzle_data = load_examples(106)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(106, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3946.65it/s]
# 262it [00:00, 37432.56it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 85 bytes.
# Next steps:
#  * Copy it into a file named task106.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 107](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task107.py)

# %%
puzzle_data = load_examples(107)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(107, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 189.66it/s]
# 262it [00:01, 138.08it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 188 bytes.
# Next steps:
#  * Copy it into a file named task107.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 108](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task108.py)

# %%
puzzle_data = load_examples(108)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(108, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3998.38it/s]
# 262it [00:00, 4677.30it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 68 bytes.
# Next steps:
#  * Copy it into a file named task108.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 109](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task109.py)

# %%
puzzle_data = load_examples(109)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(109, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 12421.95it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 111 bytes.
# Next steps:
#  * Copy it into a file named task109.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 110](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task110.py)

# %%
puzzle_data = load_examples(110)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(110, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 19.80it/s]
# 262it [00:12, 20.31it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 134 bytes.
# Next steps:
#  * Copy it into a file named task110.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 111](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task111.py)

# %%
puzzle_data = load_examples(111)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(111, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 18643.57it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 94 bytes.
# Next steps:
#  * Copy it into a file named task111.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 112](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task112.py)

# %%
puzzle_data = load_examples(112)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(112, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4165.15it/s]
# 262it [00:00, 3692.22it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 175 bytes.
# Next steps:
#  * Copy it into a file named task112.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 113](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task113.py)

# %%
puzzle_data = load_examples(113)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(113, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3000.93it/s]
# 262it [00:00, 15449.50it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 28 bytes.
# Next steps:
#  * Copy it into a file named task113.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 114](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task114.py)

# %%
puzzle_data = load_examples(114)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(114, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3940.16it/s]
# 262it [00:00, 42979.80it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 68 bytes.
# Next steps:
#  * Copy it into a file named task114.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 115](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task115.py)

# %%
puzzle_data = load_examples(115)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(115, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 15348.52it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 86 bytes.
# Next steps:
#  * Copy it into a file named task115.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 116](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task116.py)

# %%
puzzle_data = load_examples(116)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(116, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 29039.36it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 20 bytes.
# Next steps:
#  * Copy it into a file named task116.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 117](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task117.py)

# %%
puzzle_data = load_examples(117)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(117, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3808.68it/s]
# 261it [00:00, 6692.79it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 239 bytes.
# Next steps:
#  * Copy it into a file named task117.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 118](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task118.py)

# %%
puzzle_data = load_examples(118)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(118, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 718.52it/s]
# 262it [00:00, 584.66it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 422 bytes.
# Next steps:
#  * Copy it into a file named task118.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 119](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task119.py)

# %%
puzzle_data = load_examples(119)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(119, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4005.06it/s]
# 262it [00:00, 6232.04it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 227 bytes.
# Next steps:
#  * Copy it into a file named task119.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 120](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task120.py)

# %%
puzzle_data = load_examples(120)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(120, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4060.31it/s]
# 262it [00:00, 4758.51it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 122 bytes.
# Next steps:
#  * Copy it into a file named task120.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 121](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task121.py)

# %%
puzzle_data = load_examples(121)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:4])

verify_program(121, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 14477.03it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 121 bytes.
# Next steps:
#  * Copy it into a file named task121.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 122](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task122.py)

# %%
puzzle_data = load_examples(122)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(122, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4478.70it/s]
# 262it [00:00, 5029.00it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task122.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 123](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task123.py)

# %%
puzzle_data = load_examples(123)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(123, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3559.02it/s]
# 261it [00:00, 13067.77it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 77 bytes.
# Next steps:
#  * Copy it into a file named task123.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 124](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task124.py)

# %%
puzzle_data = load_examples(124)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(124, puzzle_data)
# Out:
# num problems: 3
# 5it [00:00, ?it/s]
# 262it [00:00, 9358.54it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task124.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 125](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task125.py)

# %%
puzzle_data = load_examples(125)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(125, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1499.93it/s]
# 262it [00:00, 2593.85it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 228 bytes.
# Next steps:
#  * Copy it into a file named task125.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 126](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task126.py)

# %%
puzzle_data = load_examples(126)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(126, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13099.54it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 62 bytes.
# Next steps:
#  * Copy it into a file named task126.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 127](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task127.py)

# %%
puzzle_data = load_examples(127)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(127, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 9361.09it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 94 bytes.
# Next steps:
#  * Copy it into a file named task127.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 128](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task128.py)

# %%
puzzle_data = load_examples(128)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(128, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3532.79it/s]
# 262it [00:00, 6225.05it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task128.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 129](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task129.py)

# %%
puzzle_data = load_examples(129)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(129, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3994.58it/s]
# 261it [00:00, 52208.76it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 48 bytes.
# Next steps:
#  * Copy it into a file named task129.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 130](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task130.py)

# %%
puzzle_data = load_examples(130)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(130, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 25970.92it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 86 bytes.
# Next steps:
#  * Copy it into a file named task130.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 131](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task131.py)

# %%
puzzle_data = load_examples(131)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(131, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3963.43it/s]
# 262it [00:00, 11397.57it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 210 bytes.
# Next steps:
#  * Copy it into a file named task131.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 132](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task132.py)

# %%
puzzle_data = load_examples(132)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(132, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1656.78it/s]
# 262it [00:00, 939.46it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 147 bytes.
# Next steps:
#  * Copy it into a file named task132.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 133](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task133.py)

# %%
puzzle_data = load_examples(133)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(133, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5000.36it/s]
# 262it [00:00, 2785.85it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 476 bytes.
# Next steps:
#  * Copy it into a file named task133.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 134](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task134.py)

# %%
puzzle_data = load_examples(134)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(134, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3884.51it/s]
# 262it [00:00, 2805.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 224 bytes.
# Next steps:
#  * Copy it into a file named task134.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 135](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task135.py)

# %%
puzzle_data = load_examples(135)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(135, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 261it [00:00, 29004.41it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 32 bytes.
# Next steps:
#  * Copy it into a file named task135.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 136](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task136.py)

# %%
puzzle_data = load_examples(136)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(136, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 9358.38it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 162 bytes.
# Next steps:
#  * Copy it into a file named task136.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 137](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task137.py)

# %%
puzzle_data = load_examples(137)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(137, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 654.59it/s]
# 262it [00:00, 669.91it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 255 bytes.
# Next steps:
#  * Copy it into a file named task137.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 138](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task138.py)

# %%
puzzle_data = load_examples(138)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(138, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3995.53it/s]
# 262it [00:00, 2015.43it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 204 bytes.
# Next steps:
#  * Copy it into a file named task138.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 139](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task139.py)

# %%
puzzle_data = load_examples(139)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(139, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 948.15it/s]
# 262it [00:00, 1743.31it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 157 bytes.
# Next steps:
#  * Copy it into a file named task139.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 140](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task140.py)

# %%
puzzle_data = load_examples(140)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(140, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 52346.38it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 36 bytes.
# Next steps:
#  * Copy it into a file named task140.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 141](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task141.py)

# %%
puzzle_data = load_examples(141)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(141, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3954.09it/s]
# 261it [00:00, 6214.14it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 123 bytes.
# Next steps:
#  * Copy it into a file named task141.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 142](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task142.py)

# %%
puzzle_data = load_examples(142)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(142, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 29114.76it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 40 bytes.
# Next steps:
#  * Copy it into a file named task142.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 143](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task143.py)

# %%
puzzle_data = load_examples(143)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(143, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3998.38it/s]
# 262it [00:00, 8188.64it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 279 bytes.
# Next steps:
#  * Copy it into a file named task143.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 144](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task144.py)

# %%
puzzle_data = load_examples(144)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(144, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4997.98it/s]
# 262it [00:00, 32765.07it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 68 bytes.
# Next steps:
#  * Copy it into a file named task144.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 145](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task145.py)

# %%
puzzle_data = load_examples(145)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(145, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1218.14it/s]
# 262it [00:00, 1191.21it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 363 bytes.
# Next steps:
#  * Copy it into a file named task145.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 146](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task146.py)

# %%
puzzle_data = load_examples(146)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(146, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 37430.01it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 85 bytes.
# Next steps:
#  * Copy it into a file named task146.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 147](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task147.py)

# %%
puzzle_data = load_examples(147)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(147, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 23841.61it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 155 bytes.
# Next steps:
#  * Copy it into a file named task147.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 148](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task148.py)

# %%
puzzle_data = load_examples(148)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(148, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4000.29it/s]
# 262it [00:00, 4226.03it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 171 bytes.
# Next steps:
#  * Copy it into a file named task148.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 149](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task149.py)

# %%
puzzle_data = load_examples(149)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(149, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5007.53it/s]
# 262it [00:00, 17469.04it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 139 bytes.
# Next steps:
#  * Copy it into a file named task149.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 150](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task150.py)

# %%
puzzle_data = load_examples(150)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(150, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 26203.15it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 30 bytes.
# Next steps:
#  * Copy it into a file named task150.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 151](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task151.py)

# %%
puzzle_data = load_examples(151)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(151, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3998.38it/s]
# 262it [00:00, 17469.60it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 131 bytes.
# Next steps:
#  * Copy it into a file named task151.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 152](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task152.py)

# %%
puzzle_data = load_examples(152)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(152, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5002.75it/s]
# 262it [00:00, 29123.25it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 40 bytes.
# Next steps:
#  * Copy it into a file named task152.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 153](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task153.py)

# %%
puzzle_data = load_examples(153)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(153, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 24.84it/s]
# 261it [00:11, 23.62it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 209 bytes.
# Next steps:
#  * Copy it into a file named task153.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 154](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task154.py)

# %%
puzzle_data = load_examples(154)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(154, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1333.96it/s]
# 262it [00:00, 2786.09it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 187 bytes.
# Next steps:
#  * Copy it into a file named task154.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 155](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task155.py)

# %%
puzzle_data = load_examples(155)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(155, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 26206.90it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 18 bytes.
# Next steps:
#  * Copy it into a file named task155.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 156](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task156.py)

# %%
puzzle_data = load_examples(156)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(156, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2993.79it/s]
# 262it [00:00, 4555.34it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 249 bytes.
# Next steps:
#  * Copy it into a file named task156.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 157](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task157.py)

# %%
puzzle_data = load_examples(157)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(157, puzzle_data)
# Out:
# num problems: 2
# 3it [00:04,  1.65s/it]
# 262it [09:12,  2.11s/it]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 275 bytes.
# Next steps:
#  * Copy it into a file named task157.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 158](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task158.py)

# %%
puzzle_data = load_examples(158)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(158, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 18.78it/s]
# 262it [00:14, 18.25it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 510 bytes.
# Next steps:
#  * Copy it into a file named task158.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 159](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task159.py)

# %%
puzzle_data = load_examples(159)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(159, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4000.29it/s]
# 261it [00:00, 5807.99it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 200 bytes.
# Next steps:
#  * Copy it into a file named task159.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 160](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task160.py)

# %%
puzzle_data = load_examples(160)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(160, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 9055.54it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 151 bytes.
# Next steps:
#  * Copy it into a file named task160.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 161](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task161.py)

# %%
puzzle_data = load_examples(161)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(161, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, 1331.74it/s]
# 262it [00:00, 1522.65it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 145 bytes.
# Next steps:
#  * Copy it into a file named task161.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 162](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task162.py)

# %%
puzzle_data = load_examples(162)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(162, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1991.36it/s]
# 262it [00:00, 2943.90it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 148 bytes.
# Next steps:
#  * Copy it into a file named task162.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 163](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task163.py)

# %%
puzzle_data = load_examples(163)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(163, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5000.36it/s]
# 262it [00:00, 7486.26it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 188 bytes.
# Next steps:
#  * Copy it into a file named task163.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 164](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task164.py)

# %%
puzzle_data = load_examples(164)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(164, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4989.66it/s]
# 262it [00:00, 37474.68it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 32 bytes.
# Next steps:
#  * Copy it into a file named task164.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 165](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task165.py)

# %%
puzzle_data = load_examples(165)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(165, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 999.89it/s]
# 261it [00:00, 1403.25it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 203 bytes.
# Next steps:
#  * Copy it into a file named task165.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 166](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task166.py)

# %%
puzzle_data = load_examples(166)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(166, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 8042.42it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 76 bytes.
# Next steps:
#  * Copy it into a file named task166.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 167](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task167.py)

# %%
puzzle_data = load_examples(167)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(167, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 37454.25it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 82 bytes.
# Next steps:
#  * Copy it into a file named task167.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 168](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task168.py)

# %%
puzzle_data = load_examples(168)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(168, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3010.27it/s]
# 262it [00:00, 4490.47it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 188 bytes.
# Next steps:
#  * Copy it into a file named task168.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 169](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task169.py)

# %%
puzzle_data = load_examples(169)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(169, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 974.80it/s]
# 262it [00:00, 1139.49it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 158 bytes.
# Next steps:
#  * Copy it into a file named task169.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 170](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task170.py)

# %%
puzzle_data = load_examples(170)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(170, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4001.24it/s]
# 262it [00:00, 3451.93it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 256 bytes.
# Next steps:
#  * Copy it into a file named task170.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 171](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task171.py)

# %%
puzzle_data = load_examples(171)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(171, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 49it [00:00, 16334.52it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 49 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task171.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 172](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task172.py)

# %%
puzzle_data = load_examples(172)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(172, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 42986.53it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 20 bytes.
# Next steps:
#  * Copy it into a file named task172.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 173](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task173.py)

# %%
puzzle_data = load_examples(173)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(173, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 16.46it/s]
# 262it [00:28,  9.34it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 313 bytes.
# Next steps:
#  * Copy it into a file named task173.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 174](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task174.py)

# %%
puzzle_data = load_examples(174)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(174, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 799.33it/s]
# 262it [00:00, 1091.10it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 120 bytes.
# Next steps:
#  * Copy it into a file named task174.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 175](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task175.py)

# %%
puzzle_data = load_examples(175)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(175, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1996.57it/s]
# 262it [00:00, 2647.68it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 102 bytes.
# Next steps:
#  * Copy it into a file named task175.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 176](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task176.py)

# %%
puzzle_data = load_examples(176)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(176, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4001.24it/s]
# 21it [00:00, 10502.01it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 21 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 94 bytes.
# Next steps:
#  * Copy it into a file named task176.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 177](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task177.py)

# %%
puzzle_data = load_examples(177)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(177, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4014.65it/s]
# 261it [00:00, 9667.88it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 56 bytes.
# Next steps:
#  * Copy it into a file named task177.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 178](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task178.py)

# %%
puzzle_data = load_examples(178)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(178, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 32764.09it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 69 bytes.
# Next steps:
#  * Copy it into a file named task178.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 179](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task179.py)

# %%
puzzle_data = load_examples(179)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(179, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 32744.57it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 21 bytes.
# Next steps:
#  * Copy it into a file named task179.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 180](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task180.py)

# %%
puzzle_data = load_examples(180)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(180, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 17400.44it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 91 bytes.
# Next steps:
#  * Copy it into a file named task180.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 181](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task181.py)

# %%
puzzle_data = load_examples(181)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(181, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4025.24it/s]
# 262it [00:00, 15410.72it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task181.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 182](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task182.py)

# %%
puzzle_data = load_examples(182)
label = "test"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(182, puzzle_data)
# Out:
# num problems: 1
# 5it [00:00,  9.24it/s]
# 262it [00:21, 12.29it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 584 bytes.
# Next steps:
#  * Copy it into a file named task182.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 183](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task183.py)

# %%
puzzle_data = load_examples(183)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(183, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3731.59it/s]
# 261it [00:00, 25862.02it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 116 bytes.
# Next steps:
#  * Copy it into a file named task183.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 184](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task184.py)

# %%
puzzle_data = load_examples(184)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(184, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 6081.33it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 118 bytes.
# Next steps:
#  * Copy it into a file named task184.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 185](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task185.py)

# %%
puzzle_data = load_examples(185)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(185, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2504.96it/s]
# 262it [00:00, 5041.53it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 233 bytes.
# Next steps:
#  * Copy it into a file named task185.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 186](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task186.py)

# %%
puzzle_data = load_examples(186)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(186, puzzle_data)
# Out:
# num problems: 10
# 12it [00:00, ?it/s]
# 255it [00:00, 42547.04it/s]
# Results on ARC-AGI examples: 12 pass, 0 fail
# Results on ARC-GEN examples: 255 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 92 bytes.
# Next steps:
#  * Copy it into a file named task186.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 187](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task187.py)

# %%
puzzle_data = load_examples(187)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(187, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 70.23it/s]
# 262it [00:01, 221.48it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 109 bytes.
# Next steps:
#  * Copy it into a file named task187.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 188](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task188.py)

# %%
puzzle_data = load_examples(188)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(188, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 43921.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 85 bytes.
# Next steps:
#  * Copy it into a file named task188.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 189](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task189.py)

# %%
puzzle_data = load_examples(189)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(189, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 17518.89it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task189.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 190](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task190.py)

# %%
puzzle_data = load_examples(190)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(190, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 6895.76it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 223 bytes.
# Next steps:
#  * Copy it into a file named task190.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 191](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task191.py)

# %%
puzzle_data = load_examples(191)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[2:4])

# TODO
verify_program(191, puzzle_data)
# Out:
# num problems: 262
# 5it [00:00, 56.23it/s]
# 262it [00:04, 60.75it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 635 bytes.
# Next steps:
#  * Copy it into a file named task191.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # Tasl 192

# %%
puzzle_data = load_examples(192)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(192, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3002.37it/s]
# 262it [00:00, 1858.18it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 177 bytes.
# Next steps:
#  * Copy it into a file named task192.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 193](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task193.py)

# %%
puzzle_data = load_examples(193)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(193, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3998.38it/s]
# 262it [00:00, 4943.62it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 133 bytes.
# Next steps:
#  * Copy it into a file named task193.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 194](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task194.py)

# %%
puzzle_data = load_examples(194)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(194, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, ?it/s]
# 262it [00:00, 26200.65it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 78 bytes.
# Next steps:
#  * Copy it into a file named task194.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 195](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task195.py)

# %%
puzzle_data = load_examples(195)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(195, puzzle_data)
# Out:
# num problems: 261
# 4it [00:00, 3966.24it/s]
# 261it [00:00, 6366.87it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 197 bytes.
# Next steps:
#  * Copy it into a file named task195.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 196](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task196.py)

# %%
puzzle_data = load_examples(196)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(196, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 573.17it/s]
# 262it [00:00, 551.27it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 129 bytes.
# Next steps:
#  * Copy it into a file named task196.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 197](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task197.py)

# %%
puzzle_data = load_examples(197)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(197, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4785.83it/s]
# 262it [00:00, 12453.90it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 54 bytes.
# Next steps:
#  * Copy it into a file named task197.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 198](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task198.py)

# %%
puzzle_data = load_examples(198)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(198, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 166.38it/s]
# 262it [00:01, 190.97it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 140 bytes.
# Next steps:
#  * Copy it into a file named task198.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 199](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task199.py)

# %%
puzzle_data = load_examples(199)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(199, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 10436.47it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 130 bytes.
# Next steps:
#  * Copy it into a file named task199.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 200](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task200.py)

# %%
puzzle_data = load_examples(200)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(200, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 80it [00:00, 8902.74it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 80 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 132 bytes.
# Next steps:
#  * Copy it into a file named task200.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 201](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task201.py)

# %%
puzzle_data = load_examples(201)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(201, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4995.60it/s]
# 261it [00:00, 10007.89it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 321 bytes.
# Next steps:
#  * Copy it into a file named task201.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 202](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task202.py)

# %%
puzzle_data = load_examples(202)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(202, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2516.68it/s]
# 262it [00:00, 2729.03it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 141 bytes.
# Next steps:
#  * Copy it into a file named task202.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 203](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task203.py)

# %%
puzzle_data = load_examples(203)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(203, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2449.66it/s]
# 262it [00:00, 6560.68it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 82 bytes.
# Next steps:
#  * Copy it into a file named task203.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 204](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task204.py)

# %%
puzzle_data = load_examples(204)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(204, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 75.98it/s]
# 262it [00:03, 82.26it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 228 bytes.
# Next steps:
#  * Copy it into a file named task204.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 205](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task205.py)

# %%
puzzle_data = load_examples(205)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# Already solved but takes time (8min,51.6secs) (252 bytes, needs optimization)
verify_program(205, puzzle_data)
# Out:
# num problems: 3
# 4it [00:04,  1.16s/it]
# 262it [08:48,  2.02s/it]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 252 bytes.
# Next steps:
#  * Copy it into a file named task205.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 206](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task206.py)

# %%
puzzle_data = load_examples(206)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(206, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 9699.87it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 239 bytes.
# Next steps:
#  * Copy it into a file named task206.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 207](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task207.py)

# %%
puzzle_data = load_examples(207)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(207, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 35742.24it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 92 bytes.
# Next steps:
#  * Copy it into a file named task207.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 208](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task208.py)

# %%
puzzle_data = load_examples(208)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(208, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 276.71it/s]
# 262it [00:00, 373.56it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 333 bytes.
# Next steps:
#  * Copy it into a file named task208.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 209](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task209.py)

# %%
puzzle_data = load_examples(209)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(209, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 799.60it/s]
# 262it [00:00, 1573.47it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 589 bytes.
# Next steps:
#  * Copy it into a file named task209.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 210](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task210.py)

# %%
puzzle_data = load_examples(210)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(210, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4001.24it/s]
# 262it [00:00, 37282.70it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 20 bytes.
# Next steps:
#  * Copy it into a file named task210.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 211](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task211.py)

# %%
puzzle_data = load_examples(211)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(211, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 26122.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 49 bytes.
# Next steps:
#  * Copy it into a file named task211.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 212](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task212.py)

# %%
puzzle_data = load_examples(212)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(212, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2903.97it/s]
# 262it [00:00, 6331.28it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 136 bytes.
# Next steps:
#  * Copy it into a file named task212.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 213](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task213.py)

# %%
puzzle_data = load_examples(213)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(213, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2081.54it/s]
# 261it [00:00, 9533.01it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 129 bytes.
# Next steps:
#  * Copy it into a file named task213.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 214](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task214.py)

# %%
puzzle_data = load_examples(214)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(214, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13851.66it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 124 bytes.
# Next steps:
#  * Copy it into a file named task214.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 215](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task215.py)

# %%
puzzle_data = load_examples(215)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(215, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3090.11it/s]
# 262it [00:00, 4852.16it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 83 bytes.
# Next steps:
#  * Copy it into a file named task215.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 216](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task216.py)

# %%
puzzle_data = load_examples(216)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(216, puzzle_data)
# Out:
# num problems: 3
# 4it [00:02,  1.68it/s]
# 262it [02:26,  1.79it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 165 bytes.
# Next steps:
#  * Copy it into a file named task216.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 217](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task217.py)

# %%
puzzle_data = load_examples(217)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(217, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3996.48it/s]
# 262it [00:00, 10919.95it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 145 bytes.
# Next steps:
#  * Copy it into a file named task217.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 218](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task218.py)

# %%
puzzle_data = load_examples(218)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(218, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4552.84it/s]
# 262it [00:00, 9001.32it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 81 bytes.
# Next steps:
#  * Copy it into a file named task218.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %%
puzzle_data = load_examples(219)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(219, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1333.96it/s]
# 261it [00:00, 1715.98it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 1823 bytes.
# Next steps:
#  * Copy it into a file named task219.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 220](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task220.py)

# %%
puzzle_data = load_examples(220)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(220, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2511.56it/s]
# 262it [00:00, 2671.01it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 183 bytes.
# Next steps:
#  * Copy it into a file named task220.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 221](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task221.py)

# %%
puzzle_data = load_examples(221)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(221, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4996.79it/s]
# 262it [00:00, 5458.46it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 106 bytes.
# Next steps:
#  * Copy it into a file named task221.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 222](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task222.py)

# %%
puzzle_data = load_examples(222)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(222, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2114.06it/s]
# 262it [00:00, 2004.65it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 233 bytes.
# Next steps:
#  * Copy it into a file named task222.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 223](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task223.py)

# %%
puzzle_data = load_examples(223)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(223, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3274.24it/s]
# 262it [00:00, 12477.80it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 59 bytes.
# Next steps:
#  * Copy it into a file named task223.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 224](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task224.py)

# %%
puzzle_data = load_examples(224)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(224, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4031.05it/s]
# 262it [00:00, 4294.40it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 231 bytes.
# Next steps:
#  * Copy it into a file named task224.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 225](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task225.py)

# %%
puzzle_data = load_examples(225)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(225, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3996.48it/s]
# 261it [00:00, 2779.71it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 202 bytes.
# Next steps:
#  * Copy it into a file named task225.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 226](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task226.py)

# %%
puzzle_data = load_examples(226)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(226, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2116.20it/s]
# 129it [00:00, 4969.24it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 129 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 244 bytes.
# Next steps:
#  * Copy it into a file named task226.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 227](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task227.py)

# %%
puzzle_data = load_examples(227)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(227, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4990.84it/s]
# 262it [00:00, 20119.14it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 68 bytes.
# Next steps:
#  * Copy it into a file named task227.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 228](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task228.py)

# %%
puzzle_data = load_examples(228)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(228, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3971.88it/s]
# 262it [00:00, 7697.86it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 211 bytes.
# Next steps:
#  * Copy it into a file named task228.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 229](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task229.py)

# %%
puzzle_data = load_examples(229)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(229, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 43643.82it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 86 bytes.
# Next steps:
#  * Copy it into a file named task229.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 230](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task230.py)

# %%
puzzle_data = load_examples(230)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(230, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 4225.79it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 200 bytes.
# Next steps:
#  * Copy it into a file named task230.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 231](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task231.py)

# %%
puzzle_data = load_examples(231)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(231, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3995.53it/s]
# 262it [00:00, 11901.31it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 55 bytes.
# Next steps:
#  * Copy it into a file named task231.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 232](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task232.py)

# %%
puzzle_data = load_examples(232)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(232, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4001.24it/s]
# 262it [00:00, 6238.05it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 95 bytes.
# Next steps:
#  * Copy it into a file named task232.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 233](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task233.py)

# %%
puzzle_data = load_examples(233)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(233, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1000.31it/s]
# 262it [00:00, 598.03it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 570 bytes.
# Next steps:
#  * Copy it into a file named task233.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 234](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task234.py)

# %%
puzzle_data = load_examples(234)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(234, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2041.27it/s]
# 262it [00:00, 2260.57it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 119 bytes.
# Next steps:
#  * Copy it into a file named task234.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 235](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task235.py)

# %%
puzzle_data = load_examples(235)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(235, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5030.35it/s]
# 64it [00:00, 31998.50it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 64 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 73 bytes.
# Next steps:
#  * Copy it into a file named task235.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 236](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task236.py)

# %%
puzzle_data = load_examples(236)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(236, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5515.92it/s]
# 262it [00:00, 26473.96it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 70 bytes.
# Next steps:
#  * Copy it into a file named task236.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 237](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task237.py)

# %%
puzzle_data = load_examples(237)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(237, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4569.95it/s]
# 261it [00:00, 11345.94it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 136 bytes.
# Next steps:
#  * Copy it into a file named task237.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 238](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task238.py)

# %%
puzzle_data = load_examples(238)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(238, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1966.39it/s]
# 262it [00:00, 2814.80it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 354 bytes.
# Next steps:
#  * Copy it into a file named task238.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 239](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task239.py)

# %%
puzzle_data = load_examples(239)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(239, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5201.27it/s]
# 262it [00:00, 18746.61it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 118 bytes.
# Next steps:
#  * Copy it into a file named task239.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 240](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task240.py)

# %%
puzzle_data = load_examples(240)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(240, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 138.23it/s]
# 262it [00:01, 136.94it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 155 bytes.
# Next steps:
#  * Copy it into a file named task240.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 241](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task241.py)

# %%
puzzle_data = load_examples(241)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(241, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 21829.28it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 21 bytes.
# Next steps:
#  * Copy it into a file named task241.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 242](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task242.py)

# %%
puzzle_data = load_examples(242)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(242, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3767.62it/s]
# 262it [00:00, 13096.58it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 86 bytes.
# Next steps:
#  * Copy it into a file named task242.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 243](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task243.py)

# %%
puzzle_data = load_examples(243)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(243, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 502.88it/s]
# 261it [00:00, 556.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 148 bytes.
# Next steps:
#  * Copy it into a file named task243.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 244](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task244.py)

# %%
puzzle_data = load_examples(244)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(244, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3806.95it/s]
# 262it [00:00, 12475.96it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 123 bytes.
# Next steps:
#  * Copy it into a file named task244.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 245](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task245.py)

# %%
puzzle_data = load_examples(245)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(245, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4971.91it/s]
# 262it [00:00, 10485.46it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 244 bytes.
# Next steps:
#  * Copy it into a file named task245.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 246](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task246.py)

# %%
puzzle_data = load_examples(246)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(246, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1998.48it/s]
# 262it [00:00, 3354.58it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 198 bytes.
# Next steps:
#  * Copy it into a file named task246.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 247](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task247.py)

# %%
puzzle_data = load_examples(247)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(247, puzzle_data)
# Out:
# num problems: 6
# 7it [00:00, 6959.03it/s]
# 262it [00:00, 17599.98it/s]
# Results on ARC-AGI examples: 7 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 127 bytes.
# Next steps:
#  * Copy it into a file named task247.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 248](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task248.py)

# %%
puzzle_data = load_examples(248)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(248, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 9it [00:00, 8994.22it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 9 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 93 bytes.
# Next steps:
#  * Copy it into a file named task248.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 249](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task249.py)

# %%
puzzle_data = load_examples(249)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(249, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 32660.46it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 27 bytes.
# Next steps:
#  * Copy it into a file named task249.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 250](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task250.py)

# %%
puzzle_data = load_examples(250)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(250, puzzle_data)
# Out:
# num problems: 262
# 3it [00:00, 2976.79it/s]
# 262it [00:00, 7488.25it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 261 bytes.
# Next steps:
#  * Copy it into a file named task250.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 251](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task251.py)

# %%
puzzle_data = load_examples(251)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(251, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 786.63it/s]
# 262it [00:00, 656.40it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 124 bytes.
# Next steps:
#  * Copy it into a file named task251.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 252](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task252.py)

# %%
puzzle_data = load_examples(252)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(252, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2100.57it/s]
# 262it [00:00, 10915.18it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 62 bytes.
# Next steps:
#  * Copy it into a file named task252.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 253](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task253.py)

# %%
puzzle_data = load_examples(253)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(253, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3011.71it/s]
# 262it [00:00, 6698.98it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 225 bytes.
# Next steps:
#  * Copy it into a file named task253.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 254](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task254.py)

# %%
puzzle_data = load_examples(254)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(254, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2976.09it/s]
# 262it [00:00, 10296.72it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 116 bytes.
# Next steps:
#  * Copy it into a file named task254.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 255](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task255.py)

# %%
puzzle_data = load_examples(255)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(255, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 30.03it/s]
# 261it [00:06, 39.18it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 1436 bytes.
# Next steps:
#  * Copy it into a file named task255.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 256](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task256.py)

# %%
puzzle_data = load_examples(256)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(256, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4008.89it/s]
# 262it [00:00, 10919.74it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task256.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 257](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task257.py)

# %%
puzzle_data = load_examples(257)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(257, puzzle_data)
# Out:
# num problems: 6
# 7it [00:00, 6932.73it/s]
# 262it [00:00, 13796.71it/s]
# Results on ARC-AGI examples: 7 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 95 bytes.
# Next steps:
#  * Copy it into a file named task257.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 258](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task258.py)

# %%
puzzle_data = load_examples(258)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(258, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3930.93it/s]
# 262it [00:00, 12467.33it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 71 bytes.
# Next steps:
#  * Copy it into a file named task258.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 259](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task259.py)

# %%
puzzle_data = load_examples(259)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(259, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 30482.88it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task259.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 260](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task260.py)

# %%
puzzle_data = load_examples(260)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(260, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1013.12it/s]
# 262it [00:00, 1077.57it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 198 bytes.
# Next steps:
#  * Copy it into a file named task260.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 261](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task261.py)

# %%
puzzle_data = load_examples(261)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(261, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 13664.27it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 52 bytes.
# Next steps:
#  * Copy it into a file named task261.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 262](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task262.py)

# %%
puzzle_data = load_examples(262)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(262, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4969.55it/s]
# 6it [00:00, ?it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 6 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 47 bytes.
# Next steps:
#  * Copy it into a file named task262.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 263](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task263.py)

# %%
puzzle_data = load_examples(263)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(263, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4983.73it/s]
# 262it [00:00, 21921.60it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 218 bytes.
# Next steps:
#  * Copy it into a file named task263.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 264](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task264.py)

# %%
puzzle_data = load_examples(264)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(264, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 374.60it/s]
# 262it [00:00, 400.47it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 286 bytes.
# Next steps:
#  * Copy it into a file named task264.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 265](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task265.py)

# %%
puzzle_data = load_examples(265)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(265, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 494.13it/s]
# 262it [00:00, 477.84it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 197 bytes.
# Next steps:
#  * Copy it into a file named task265.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 266](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task266.py)

# %%
puzzle_data = load_examples(266)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(266, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 15it [00:00, ?it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 15 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 158 bytes.
# Next steps:
#  * Copy it into a file named task266.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 267](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task267.py)

# %%
puzzle_data = load_examples(267)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(267, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3040.09it/s]
# 261it [00:00, 17416.76it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 60 bytes.
# Next steps:
#  * Copy it into a file named task267.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 268](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task268.py)

# %%
puzzle_data = load_examples(268)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(268, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 11910.99it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 492 bytes.
# Next steps:
#  * Copy it into a file named task268.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 269](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task269.py)

# %%
puzzle_data = load_examples(269)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(269, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3992.67it/s]
# 262it [00:00, 5935.97it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 88 bytes.
# Next steps:
#  * Copy it into a file named task269.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 270](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task270.py)

# %%
puzzle_data = load_examples(270)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(270, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1995.86it/s]
# 262it [00:00, 3275.15it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 223 bytes.
# Next steps:
#  * Copy it into a file named task270.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 271](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task271.py)

# %%
puzzle_data = load_examples(271)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(271, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 7278.79it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 126 bytes.
# Next steps:
#  * Copy it into a file named task271.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 272](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task272.py)

# %%
puzzle_data = load_examples(272)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(272, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5006.33it/s]
# 262it [00:00, 29114.76it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 135 bytes.
# Next steps:
#  * Copy it into a file named task272.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 273](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task273.py)

# %%
puzzle_data = load_examples(273)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(273, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1998.95it/s]
# 262it [00:00, 3794.41it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 166 bytes.
# Next steps:
#  * Copy it into a file named task273.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 274](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task274.py)

# %%
puzzle_data = load_examples(274)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(274, puzzle_data)
# Out:
# num problems: 6
# 7it [00:00, ?it/s]
# 262it [00:00, 23900.73it/s]
# Results on ARC-AGI examples: 7 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 109 bytes.
# Next steps:
#  * Copy it into a file named task274.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 275](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task275.py)

# %%
puzzle_data = load_examples(275)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(275, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3993.62it/s]
# 262it [00:00, 8170.26it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 189 bytes.
# Next steps:
#  * Copy it into a file named task275.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 276](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task276.py)

# %%
puzzle_data = load_examples(276)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(276, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 16376.68it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 40 bytes.
# Next steps:
#  * Copy it into a file named task276.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 277](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task277.py)

# %%
puzzle_data = load_examples(277)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(277, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 10.44it/s]
# 262it [00:23, 11.20it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 229 bytes.
# Next steps:
#  * Copy it into a file named task277.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 278](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task278.py)

# %%
puzzle_data = load_examples(278)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# NEEDS TO BE REDONE
verify_program(278, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1425.34it/s]
# 262it [00:00, 4596.52it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 278 bytes.
# Next steps:
#  * Copy it into a file named task278.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 279](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task279.py)

# %%
puzzle_data = load_examples(279)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(279, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 90.89it/s]
# 261it [00:00, 355.29it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 131 bytes.
# Next steps:
#  * Copy it into a file named task279.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 280](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task280.py)

# %%
puzzle_data = load_examples(280)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(280, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1666.26it/s]
# 262it [00:00, 3119.62it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 266 bytes.
# Next steps:
#  * Copy it into a file named task280.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 281](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task281.py)

# %%
puzzle_data = load_examples(281)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(281, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 666.69it/s]
# 262it [00:00, 590.77it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 219 bytes.
# Next steps:
#  * Copy it into a file named task281.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 282](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task282.py)

# %%
puzzle_data = load_examples(282)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(282, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3052.62it/s]
# 262it [00:00, 6894.20it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 157 bytes.
# Next steps:
#  * Copy it into a file named task282.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 283](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task283.py)

# %%
puzzle_data = load_examples(283)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(283, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2705.42it/s]
# 262it [00:00, 5695.98it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 140 bytes.
# Next steps:
#  * Copy it into a file named task283.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 284](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task284.py)

# %%
puzzle_data = load_examples(284)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(284, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3831.29it/s]
# 262it [00:00, 8734.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 306 bytes.
# Next steps:
#  * Copy it into a file named task284.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 285](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task285.py)

# %%
puzzle_data = load_examples(285)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(285, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 173.91it/s]
# 261it [00:01, 149.21it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 323 bytes.
# Next steps:
#  * Copy it into a file named task285.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 286](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task286.py)

# %%
puzzle_data = load_examples(286)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(286, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1509.29it/s]
# 262it [00:00, 1541.35it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 251 bytes.
# Next steps:
#  * Copy it into a file named task286.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 287](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task287.py)

# %%
puzzle_data = load_examples(287)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(287, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1601.37it/s]
# 262it [00:00, 5047.71it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 76 bytes.
# Next steps:
#  * Copy it into a file named task287.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 288](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task288.py)

# %%
puzzle_data = load_examples(288)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(288, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 17359.76it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 116 bytes.
# Next steps:
#  * Copy it into a file named task288.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 289](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task289.py)

# %%
puzzle_data = load_examples(289)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(289, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 14539.66it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 92 bytes.
# Next steps:
#  * Copy it into a file named task289.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 290](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task290.py)

# %%
puzzle_data = load_examples(290)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(290, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4472.73it/s]
# 262it [00:00, 13170.82it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 86 bytes.
# Next steps:
#  * Copy it into a file named task290.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 291](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task291.py)

# %%
puzzle_data = load_examples(291)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(291, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3953.16it/s]
# 261it [00:00, 10043.15it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task291.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 292](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task292.py)

# %%
puzzle_data = load_examples(292)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(292, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 22it [00:00, 7576.54it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 22 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 65 bytes.
# Next steps:
#  * Copy it into a file named task292.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 293](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task293.py)

# %%
puzzle_data = load_examples(293)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(293, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5412.01it/s]
# 262it [00:00, 7914.12it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task293.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 294](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task294.py)

# %%
puzzle_data = load_examples(294)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(294, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2741.38it/s]
# 262it [00:00, 4952.78it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 111 bytes.
# Next steps:
#  * Copy it into a file named task294.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 295](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task295.py)

# %%
puzzle_data = load_examples(295)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(295, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 5997.57it/s]
# 262it [00:00, 10077.01it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 67 bytes.
# Next steps:
#  * Copy it into a file named task295.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 296](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task296.py)

# %%
puzzle_data = load_examples(296)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(296, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 32748.47it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 90 bytes.
# Next steps:
#  * Copy it into a file named task296.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 297](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task297.py)

# %%
puzzle_data = load_examples(297)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(297, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3996.48it/s]
# 261it [00:00, 14525.10it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 52 bytes.
# Next steps:
#  * Copy it into a file named task297.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 298](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task298.py)

# %%
puzzle_data = load_examples(298)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(298, puzzle_data)
# Out:
# num problems: 3
# 5it [00:00, 5001.55it/s]
# 262it [00:00, 19985.95it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 99 bytes.
# Next steps:
#  * Copy it into a file named task298.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 299](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task299.py)

# %%
puzzle_data = load_examples(299)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(299, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3095.43it/s]
# 18it [00:00, 8950.50it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 18 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 109 bytes.
# Next steps:
#  * Copy it into a file named task299.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 300](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task300.py)

# %%
puzzle_data = load_examples(300)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(300, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 17466.82it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 115 bytes.
# Next steps:
#  * Copy it into a file named task300.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 301](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task301.py)

# %%
puzzle_data = load_examples(301)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(301, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 16377.16it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 37 bytes.
# Next steps:
#  * Copy it into a file named task301.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 302](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task302.py)

# %%
puzzle_data = load_examples(302)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(302, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 333.38it/s]
# 262it [00:00, 301.22it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 217 bytes.
# Next steps:
#  * Copy it into a file named task302.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 303](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task303.py)

# %%
puzzle_data = load_examples(303)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(303, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2096.37it/s]
# 261it [00:00, 2269.54it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 77 bytes.
# Next steps:
#  * Copy it into a file named task303.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 304](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task304.py)

# %%
puzzle_data = load_examples(304)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(304, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4018.49it/s]
# 262it [00:00, 13102.51it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 116 bytes.
# Next steps:
#  * Copy it into a file named task304.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 305](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task305.py)

# %%
puzzle_data = load_examples(305)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(305, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4006.02it/s]
# 262it [00:00, 4233.13it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 65 bytes.
# Next steps:
#  * Copy it into a file named task305.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 306](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task306.py)

# %%
puzzle_data = load_examples(306)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(306, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1000.87it/s]
# 262it [00:00, 1735.13it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task306.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 307](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task307.py)

# %%
puzzle_data = load_examples(307)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(307, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 20154.94it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 74 bytes.
# Next steps:
#  * Copy it into a file named task307.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 308](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task308.py)

# %%
puzzle_data = load_examples(308)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(308, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4128.25it/s]
# 262it [00:00, 6390.48it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 342 bytes.
# Next steps:
#  * Copy it into a file named task308.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 309](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task309.py)

# %%
puzzle_data = load_examples(309)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(309, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 23734.14it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 40 bytes.
# Next steps:
#  * Copy it into a file named task309.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 310](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task310.py)

# %%
puzzle_data = load_examples(310)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(310, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2001.34it/s]
# 262it [00:00, 3638.85it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 111 bytes.
# Next steps:
#  * Copy it into a file named task310.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 311](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task311.py)

# %%
puzzle_data = load_examples(311)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(311, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 32347.45it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 32 bytes.
# Next steps:
#  * Copy it into a file named task311.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 312](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task312.py)

# %%
puzzle_data = load_examples(312)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(312, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3141.80it/s]
# 262it [00:00, 7277.78it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 46 bytes.
# Next steps:
#  * Copy it into a file named task312.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 313](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task313.py)

# %%
puzzle_data = load_examples(313)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(313, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 7938.59it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 81 bytes.
# Next steps:
#  * Copy it into a file named task313.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 314](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task314.py)

# %%
puzzle_data = load_examples(314)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(314, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13122.54it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 151 bytes.
# Next steps:
#  * Copy it into a file named task314.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 315](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task315.py)

# %%
puzzle_data = load_examples(315)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(315, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13794.28it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 76 bytes.
# Next steps:
#  * Copy it into a file named task315.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 316](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task316.py)

# %%
puzzle_data = load_examples(316)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(316, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 18714.69it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task316.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 317](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task317.py)

# %%
puzzle_data = load_examples(317)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(317, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 11840.66it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 78 bytes.
# Next steps:
#  * Copy it into a file named task317.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 318](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task318.py)

# %%
puzzle_data = load_examples(318)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(318, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 13783.21it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 70 bytes.
# Next steps:
#  * Copy it into a file named task318.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 319](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task319.py)

# %%
puzzle_data = load_examples(319)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(319, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 17.92it/s]
# 262it [00:11, 21.96it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 395 bytes.
# Next steps:
#  * Copy it into a file named task319.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 320](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task320.py)

# %%
puzzle_data = load_examples(320)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(320, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4194.30it/s]
# 262it [00:00, 10481.66it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 94 bytes.
# Next steps:
#  * Copy it into a file named task320.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 321](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task321.py)

# %%
puzzle_data = load_examples(321)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(321, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 261it [00:00, 32627.36it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 73 bytes.
# Next steps:
#  * Copy it into a file named task321.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 322](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task322.py)

# %%
puzzle_data = load_examples(322)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(322, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 51406.07it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 56 bytes.
# Next steps:
#  * Copy it into a file named task322.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 323](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task323.py)

# %%
puzzle_data = load_examples(323)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(323, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3082.54it/s]
# 169it [00:00, 5118.44it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 169 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 178 bytes.
# Next steps:
#  * Copy it into a file named task323.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 324](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task324.py)

# %%
puzzle_data = load_examples(324)
label = "arc-gen"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(324, puzzle_data)
# Out:
# num problems: 262
# 4it [00:00, 1954.93it/s]
# 262it [00:00, 3540.59it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 413 bytes.
# Next steps:
#  * Copy it into a file named task324.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 325](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task325.py)

# %%
puzzle_data = load_examples(325)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(325, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3957.82it/s]
# 262it [00:00, 6046.09it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 220 bytes.
# Next steps:
#  * Copy it into a file named task325.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 326](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task326.py)

# %%
puzzle_data = load_examples(326)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(326, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 23815.26it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 32 bytes.
# Next steps:
#  * Copy it into a file named task326.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 327](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task327.py)

# %%
puzzle_data = load_examples(327)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(327, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 29022.86it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 72 bytes.
# Next steps:
#  * Copy it into a file named task327.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 328](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task328.py)

# %%
puzzle_data = load_examples(328)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(328, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 456.10it/s]
# 262it [00:00, 807.90it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 175 bytes.
# Next steps:
#  * Copy it into a file named task328.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 329](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task329.py)

# %%
puzzle_data = load_examples(329)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(329, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 17432.19it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 60 bytes.
# Next steps:
#  * Copy it into a file named task329.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 330](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task330.py)

# %%
puzzle_data = load_examples(330)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(330, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 997.16it/s]
# 262it [00:00, 1119.82it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 159 bytes.
# Next steps:
#  * Copy it into a file named task330.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 331](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task331.py)

# %%
puzzle_data = load_examples(331)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(331, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 3206.65it/s]
# 262it [00:00, 7704.44it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 118 bytes.
# Next steps:
#  * Copy it into a file named task331.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 332](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task332.py)

# %%
puzzle_data = load_examples(332)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(332, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4955.46it/s]
# 262it [00:00, 21833.18it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 74 bytes.
# Next steps:
#  * Copy it into a file named task332.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 333](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task333.py)

# %%
puzzle_data = load_examples(333)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(333, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1328.36it/s]
# 261it [00:00, 2269.48it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 115 bytes.
# Next steps:
#  * Copy it into a file named task333.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 334](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task334.py)

# %%
puzzle_data = load_examples(334)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(334, puzzle_data)
# Out:
# num problems: 7
# 9it [00:00, ?it/s]
# 262it [00:00, 32755.30it/s]
# Results on ARC-AGI examples: 9 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 98 bytes.
# Next steps:
#  * Copy it into a file named task334.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 335](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task335.py)

# %%
puzzle_data = load_examples(335)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(335, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3776.95it/s]
# 262it [00:00, 6556.73it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 200 bytes.
# Next steps:
#  * Copy it into a file named task335.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 336](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task336.py)

# %%
puzzle_data = load_examples(336)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(336, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 1499.75it/s]
# 28it [00:00, 3457.69it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 28 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 147 bytes.
# Next steps:
#  * Copy it into a file named task336.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 337](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task337.py)

# %%
puzzle_data = load_examples(337)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(337, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3884.51it/s]
# 262it [00:00, 37475.96it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 51 bytes.
# Next steps:
#  * Copy it into a file named task337.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 338](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task338.py)

# %%
puzzle_data = load_examples(338)
label = "test"
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(338, puzzle_data)
# Out:
# num problems: 2
# 5it [00:00, 209.37it/s]
# 262it [00:01, 162.04it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 135 bytes.
# Next steps:
#  * Copy it into a file named task338.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 339](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task339.py)

# %%
puzzle_data = load_examples(339)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(339, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 261it [00:00, 65406.78it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 38 bytes.
# Next steps:
#  * Copy it into a file named task339.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 340](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task340.py)

# %%
puzzle_data = load_examples(340)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(340, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 571.68it/s]
# 262it [00:00, 672.99it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 161 bytes.
# Next steps:
#  * Copy it into a file named task340.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 341](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task341.py)

# %%
puzzle_data = load_examples(341)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(341, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4032.98it/s]
# 262it [00:00, 4772.22it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 172 bytes.
# Next steps:
#  * Copy it into a file named task341.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 342](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task342.py)

# %%
puzzle_data = load_examples(342)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(342, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3944.80it/s]
# 262it [00:00, 5403.38it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 185 bytes.
# Next steps:
#  * Copy it into a file named task342.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 343](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task343.py)

# %%
puzzle_data = load_examples(343)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

verify_program(343, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3615.78it/s]
# 262it [00:00, 16275.53it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 65 bytes.
# Next steps:
#  * Copy it into a file named task343.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 344](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task344.py)

# %%
puzzle_data = load_examples(344)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(344, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 6702.33it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 106 bytes.
# Next steps:
#  * Copy it into a file named task344.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 345](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task345.py)

# %%
puzzle_data = load_examples(345)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(345, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 261it [00:00, 11379.67it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 146 bytes.
# Next steps:
#  * Copy it into a file named task345.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 346](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task346.py)

# %%
puzzle_data = load_examples(346)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(346, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4530.46it/s]
# 262it [00:00, 17465.43it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 129 bytes.
# Next steps:
#  * Copy it into a file named task346.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 347](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task347.py)

# %%
puzzle_data = load_examples(347)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(347, puzzle_data)
# Out:
# num problems: 5
# 7it [00:00, ?it/s]
# 262it [00:00, 43721.96it/s]
# Results on ARC-AGI examples: 7 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task347.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 348](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task348.py)

# %%
puzzle_data = load_examples(348)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(348, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 5929.74it/s]
# 262it [00:00, 6088.60it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 125 bytes.
# Next steps:
#  * Copy it into a file named task348.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 349](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task349.py)

# %%
puzzle_data = load_examples(349)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(349, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 26.60it/s]
# 262it [00:14, 17.82it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 482 bytes.
# Next steps:
#  * Copy it into a file named task349.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 350](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task350.py)

# %%
puzzle_data = load_examples(350)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(350, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2487.43it/s]
# 262it [00:00, 3358.89it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 113 bytes.
# Next steps:
#  * Copy it into a file named task350.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 351](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task351.py)

# %%
puzzle_data = load_examples(351)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(351, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4058.35it/s]
# 261it [00:00, 9672.75it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task351.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 352](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task352.py)

# %%
puzzle_data = load_examples(352)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(352, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4062.28it/s]
# 262it [00:00, 5123.02it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 125 bytes.
# Next steps:
#  * Copy it into a file named task352.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 353](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task353.py)

# %%
puzzle_data = load_examples(353)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(353, puzzle_data)
# Out:
# num problems: 7
# 9it [00:00, ?it/s]
# 262it [00:00, 13110.01it/s]
# Results on ARC-AGI examples: 9 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 128 bytes.
# Next steps:
#  * Copy it into a file named task353.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 354](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task354.py)

# %%
puzzle_data = load_examples(354)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(354, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3968.12it/s]
# 262it [00:00, 6715.36it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 199 bytes.
# Next steps:
#  * Copy it into a file named task354.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 355](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task355.py)

# %%
puzzle_data = load_examples(355)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(355, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 1237.55it/s]
# 262it [00:00, 2301.00it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 166 bytes.
# Next steps:
#  * Copy it into a file named task355.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 356](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task356.py)

# %%
puzzle_data = load_examples(356)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(356, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4004.11it/s]
# 262it [00:00, 6550.87it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 121 bytes.
# Next steps:
#  * Copy it into a file named task356.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 357](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task357.py)

# %%
puzzle_data = load_examples(357)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

# TODO
verify_program(357, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 9it [00:00, ?it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 9 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 108 bytes.
# Next steps:
#  * Copy it into a file named task357.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 358](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task358.py)

# %%
puzzle_data = load_examples(358)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(358, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 998.41it/s]
# 262it [00:00, 2757.98it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 154 bytes.
# Next steps:
#  * Copy it into a file named task358.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 359](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task359.py)

# %%
puzzle_data = load_examples(359)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(359, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 800.90it/s]
# 262it [00:00, 738.23it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 64 bytes.
# Next steps:
#  * Copy it into a file named task359.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 360](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task360.py)

# %%
puzzle_data = load_examples(360)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(360, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 13076.32it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 53 bytes.
# Next steps:
#  * Copy it into a file named task360.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 361](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task361.py)

# %%
puzzle_data = load_examples(361)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(361, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1001.27it/s]
# 262it [00:00, 1758.35it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 244 bytes.
# Next steps:
#  * Copy it into a file named task361.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 362](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task362.py)

# %%
puzzle_data = load_examples(362)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(362, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 2498.10it/s]
# 262it [00:00, 9035.14it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 93 bytes.
# Next steps:
#  * Copy it into a file named task362.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 363](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task363.py)

# %%
puzzle_data = load_examples(363)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(363, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1955.39it/s]
# 261it [00:00, 2558.87it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 343 bytes.
# Next steps:
#  * Copy it into a file named task363.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 364](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task364.py)

# %%
puzzle_data = load_examples(364)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(364, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 20.41it/s]
# 262it [00:14, 17.92it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 523 bytes.
# Next steps:
#  * Copy it into a file named task364.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 365](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task365.py)

# %%
puzzle_data = load_examples(365)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(365, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 59.01it/s]
# 262it [00:04, 53.38it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 165 bytes.
# Next steps:
#  * Copy it into a file named task365.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 366](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task366.py)

# %%
puzzle_data = load_examples(366)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(366, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 29.42it/s]
# 262it [00:08, 32.38it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 651 bytes.
# Next steps:
#  * Copy it into a file named task366.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 367](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task367.py)

# %%
puzzle_data = load_examples(367)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(367, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 805.40it/s]
# 262it [00:00, 989.09it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 186 bytes.
# Next steps:
#  * Copy it into a file named task367.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 368](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task368.py)

# %%
puzzle_data = load_examples(368)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(368, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 9375.79it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 221 bytes.
# Next steps:
#  * Copy it into a file named task368.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 369](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task369.py)

# %%
puzzle_data = load_examples(369)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(369, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 2003.25it/s]
# 261it [00:00, 3106.93it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 221 bytes.
# Next steps:
#  * Copy it into a file named task369.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 370](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task370.py)

# %%
puzzle_data = load_examples(370)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(370, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3921.74it/s]
# 262it [00:00, 4085.54it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 325 bytes.
# Next steps:
#  * Copy it into a file named task370.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 371](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task371.py)

# %%
puzzle_data = load_examples(371)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(371, puzzle_data)
# Out:
# num problems: 2
# 4it [00:00, 4175.51it/s]
# 262it [00:00, 8449.76it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 153 bytes.
# Next steps:
#  * Copy it into a file named task371.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 372](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task372.py)

# %%
puzzle_data = load_examples(372)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(372, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4012.73it/s]
# 262it [00:00, 14498.23it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 65 bytes.
# Next steps:
#  * Copy it into a file named task372.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 373](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task373.py)

# %%
puzzle_data = load_examples(373)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(373, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 72it [00:00, 24053.36it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 72 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 53 bytes.
# Next steps:
#  * Copy it into a file named task373.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 374](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task374.py)

# %%
puzzle_data = load_examples(374)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(374, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 4847.79it/s]
# 262it [00:00, 9014.68it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 269 bytes.
# Next steps:
#  * Copy it into a file named task374.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 375](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task375.py)

# %%
puzzle_data = load_examples(375)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(375, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 54it [00:00, 10644.44it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 54 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 60 bytes.
# Next steps:
#  * Copy it into a file named task375.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 376](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task376.py)

# %%
puzzle_data = load_examples(376)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(376, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, 2990.95it/s]
# 36it [00:00, 5154.11it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 36 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 33 bytes.
# Next steps:
#  * Copy it into a file named task376.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 377](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task377.py)

# %%
puzzle_data = load_examples(377)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(377, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4000.29it/s]
# 262it [00:00, 6390.71it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 73 bytes.
# Next steps:
#  * Copy it into a file named task377.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 378](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task378.py)

# %%
puzzle_data = load_examples(378)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(378, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 207.65it/s]
# 262it [00:00, 293.68it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 209 bytes.
# Next steps:
#  * Copy it into a file named task378.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 379](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task379.py)

# %%
puzzle_data = load_examples(379)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(379, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 1302.58it/s]
# 262it [00:00, 2975.67it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 258 bytes.
# Next steps:
#  * Copy it into a file named task379.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 380](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task380.py)

# %%
puzzle_data = load_examples(380)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(380, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, ?it/s]
# 262it [00:00, 52338.90it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 27 bytes.
# Next steps:
#  * Copy it into a file named task380.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 381](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task381.py)

# %%
puzzle_data = load_examples(381)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(381, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3571.90it/s]
# 261it [00:00, 7691.97it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 99 bytes.
# Next steps:
#  * Copy it into a file named task381.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 382](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task382.py)

# %%
puzzle_data = load_examples(382)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(382, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 563.69it/s]
# 262it [00:00, 477.27it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 198 bytes.
# Next steps:
#  * Copy it into a file named task382.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 383](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task383.py)

# %%
puzzle_data = load_examples(383)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles[:3])

# TODO
verify_program(383, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 997.46it/s]
# 262it [00:00, 1430.82it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 171 bytes.
# Next steps:
#  * Copy it into a file named task383.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 384](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task384.py)

# %%
puzzle_data = load_examples(384)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(384, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3626.72it/s]
# 262it [00:00, 7072.02it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 101 bytes.
# Next steps:
#  * Copy it into a file named task384.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 385](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task385.py)

# %%
puzzle_data = load_examples(385)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(385, puzzle_data)
# Out:
# num problems: 2
# 3it [00:00, ?it/s]
# 262it [00:00, 20347.13it/s]
# Results on ARC-AGI examples: 3 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 28 bytes.
# Next steps:
#  * Copy it into a file named task385.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 386](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task386.py)

# %%
puzzle_data = load_examples(386)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(386, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 5940.94it/s]
# 262it [00:00, 32352.21it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task386.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 367](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task367.py)

# %%
puzzle_data = load_examples(387)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(387, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5570.12it/s]
# 261it [00:00, 5437.81it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 363 bytes.
# Next steps:
#  * Copy it into a file named task387.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 388](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task388.py)

# %%
puzzle_data = load_examples(388)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(388, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 4170.32it/s]
# 262it [00:00, 15427.38it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 77 bytes.
# Next steps:
#  * Copy it into a file named task388.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 389](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task389.py)

# %%
puzzle_data = load_examples(389)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(389, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 32763.12it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 74 bytes.
# Next steps:
#  * Copy it into a file named task389.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 390](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task390.py)

# %%
puzzle_data = load_examples(390)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(390, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3968.12it/s]
# 262it [00:00, 2814.17it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 187 bytes.
# Next steps:
#  * Copy it into a file named task390.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 391](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task391.py)

# %%
puzzle_data = load_examples(391)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(391, puzzle_data)
# Out:
# num problems: 4
# 5it [00:00, 5003.94it/s]
# 262it [00:00, 14465.21it/s]
# Results on ARC-AGI examples: 5 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task391.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 392](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task392.py)

# %%
puzzle_data = load_examples(392)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(392, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 666.90it/s]
# 262it [00:00, 684.57it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 161 bytes.
# Next steps:
#  * Copy it into a file named task392.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 393](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task393.py)

# %%
puzzle_data = load_examples(393)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(393, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 261it [00:00, 17411.78it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 261 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 75 bytes.
# Next steps:
#  * Copy it into a file named task393.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 394](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task394.py)

# %%
puzzle_data = load_examples(394)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(394, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3955.02it/s]
# 262it [00:00, 32833.60it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 132 bytes.
# Next steps:
#  * Copy it into a file named task394.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 395](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task395.py)

# %%
puzzle_data = load_examples(395)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(395, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, ?it/s]
# 262it [00:00, 43688.93it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 72 bytes.
# Next steps:
#  * Copy it into a file named task395.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 396](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task396.py)

# %%
puzzle_data = load_examples(396)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(396, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 49.38it/s]
# 262it [00:03, 72.52it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 296 bytes.
# Next steps:
#  * Copy it into a file named task396.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 397](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task397.py)

# %%
puzzle_data = load_examples(397)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(397, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, 3919.91it/s]
# 262it [00:00, 10077.19it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 245 bytes.
# Next steps:
#  * Copy it into a file named task397.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 398](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task398.py)

# %%
puzzle_data = load_examples(398)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(398, puzzle_data)
# Out:
# num problems: 5
# 6it [00:00, 3000.93it/s]
# 262it [00:00, 4432.94it/s]
# Results on ARC-AGI examples: 6 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 82 bytes.
# Next steps:
#  * Copy it into a file named task398.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 399](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task399.py)

# %%
puzzle_data = load_examples(399)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(399, puzzle_data)
# Out:
# num problems: 8
# 11it [00:00, 10972.02it/s]
# 262it [00:00, 38065.32it/s]
# Results on ARC-AGI examples: 11 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 84 bytes.
# Next steps:
#  * Copy it into a file named task399.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.

# %% [markdown]
# # [Task 400](https://github.com/ches-001/NeurIPS-2025---Google-Code-Golf-Solutions/tree/main/tasks/task400.py)

# %%
puzzle_data = load_examples(400)
label = LABEL
puzzles = puzzle_data[label]
print(f"num problems: {len(puzzles)}")
show_examples(puzzles)

verify_program(400, puzzle_data)
# Out:
# num problems: 3
# 4it [00:00, ?it/s]
# 262it [00:00, 5822.49it/s]
# Results on ARC-AGI examples: 4 pass, 0 fail
# Results on ARC-GEN examples: 262 pass, 0 fail
#
# Your code IS READY for submission!
# Its length appears to be 87 bytes.
# Next steps:
#  * Copy it into a file named task400.py on your local machine.
#  * Create a zip file containing that program along with all others.
#  * Submit that zip file to the Kaggle competition so that it can be officially scored.
